# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.preprocessing import LabelEncoder

# %%
CLASS_NUM = 38
EPOCHS=30
BATCH_SIZE = 30
IMAGE_SIZE = 224
IMAGE_SHAPE = (224, 224, 3)

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "color",
    shuffle=True,
    image_size= (IMAGE_SIZE,IMAGE_SIZE),
    batch_size= BATCH_SIZE
)
# Out:
# Found 54305 files belonging to 38 classes.

# %%
class_names = dataset.class_names
class_names
le = LabelEncoder()
encoded = le.fit_transform(class_names)
encoded = list(encoded)
# encoded_class = {x for x in class_names : y for y in encoded}
encoded_class = {}
for key in class_names:
    for value in encoded:
        encoded_class[key] = value
        encoded.remove(value)
        break
# le.fit_transform(class_names)

# %%
len(dataset)
# Out:
# 1811

# %%
plt.figure(figsize=(15, 15))
for image_batch, label_batch in dataset.take(1):
       for i in range(10): 
        ax = plt.subplot(4,5, i+1)    
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
# 80% ==> training
# 20% ==> 10% validation, 10% test
train_size = 0.8
len(dataset)*train_size
# Out:
# 1448.8000000000002

# %%
train_ds = dataset.take(1449)
len(train_ds)
# Out:
# 1449

# %%
test_ds = dataset.skip(1449)
len(test_ds)
# Out:
# 362

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 181.10000000000002

# %%
val_ds = test_ds.take(182)
len(val_ds)
# Out:
# 182

# %%
test_ds = dataset.skip(182)
len(test_ds)
# Out:
# 1629

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=1000):
    ds_size= len(ds)
    if shuffle:
        ds= ds.shuffle(shuffle_size, seed=12)
       
    train_size = int(train_split * ds_size)
        
    val_size = int(val_split * ds_size)
        
    train_ds = ds.take(train_size)
        
    val_ds = ds.skip(train_size).take(val_size)
        
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 1448

# %%
len(val_ds)
# Out:
# 181

# %%
len(test_ds)
# Out:
# 182

# %%
#optimiztion 
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
def process_images(image_batch, label_batch):
    # Normalize images to have a mean of 0 and standard deviation of 1
    image_batch = tf.image.per_image_standardization(image_batch)
    # Resize images from 32x32 to 277x277
    image_batch = tf.image.resize(image_batch, (227,227))
    return image_batch, label_batch

# %%
from tensorflow.keras import models, layers
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
def inception(x, filters):
    # 1x1
    path1 = Conv2D(filters=filters[0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    # 1x1->3x3
    path2 = Conv2D(filters=filters[1][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path2 = Conv2D(filters=filters[1][1], kernel_size=(3,3), strides=1, padding='same', activation='relu')(path2)
    
    # 1x1->5x5
    path3 = Conv2D(filters=filters[2][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path3 = Conv2D(filters=filters[2][1], kernel_size=(5,5), strides=1, padding='same', activation='relu')(path3)

    # 3x3->1x1
    path4 = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters=filters[3], kernel_size=(1,1), strides=1, padding='same', activation='relu')(path4)

    return Concatenate(axis=-1)([path1,path2,path3,path4])

# %%
def auxiliary(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer

# %%
def googlenet():
    layer_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    layer = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(layer_in)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    layer = Conv2D(filters=64, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=192, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    layer = inception(layer, [ 64,  (96,128), (16,32), 32]) #3a
    layer = inception(layer, [128, (128,192), (32,96), 64]) #3b
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-4
    layer = inception(layer, [192,  (96,208),  (16,48),  64]) #4a
    aux1  = auxiliary(layer, name='aux1')
    layer = inception(layer, [160, (112,224),  (24,64),  64]) #4b
    layer = inception(layer, [128, (128,256),  (24,64),  64]) #4c
    layer = inception(layer, [112, (144,288),  (32,64),  64]) #4d
    aux2  = auxiliary(layer, name='aux2')
    layer = inception(layer, [256, (160,320), (32,128), 128]) #4e
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, [256, (160,320), (32,128), 128]) #5a
    layer = inception(layer, [384, (192,384), (48,128), 128]) #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    layer = Flatten()(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=layer_in, outputs=[main, aux1, aux2])
    
    return model

# %%
import os
import time
import tensorflow as tf
from tensorflow import keras
#root_logdir = os.path.join(os.curdir, "logs\\fit\\")

#def get_run_logdir():
 #   run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
  #  return os.path.join(root_logdir, run_id)

#run_logdir = get_run_logdir()
#tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %%
model = googlenet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 56, 56, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   4160        batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 192)  768         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 528)  0           conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 832)  0           conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 832)    0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 1024)   0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 1024)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          524544      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          524544      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          262400      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# main (Dense)                    (None, 38)           9766        dense_2[0][0]
# __________________________________________________________________________________________________
# aux1 (Dense)                    (None, 38)           9766        dropout[0][0]
# __________________________________________________________________________________________________
# aux2 (Dense)                    (None, 38)           9766        dropout_1[0][0]
# ==================================================================================================
# Total params: 7,448,738
# Trainable params: 7,448,226
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD

learning_rate = 0.005
decay_rate = learning_rate / 30
sgd = SGD(learning_rate=learning_rate, momentum=0.9, decay=decay_rate, nesterov=False)

model.compile(loss='sparse_categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
history= model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/30
# 1448/1448 [==============================] - 798s 349ms/step - loss: 4.4692 - main_loss: 1.6444 - aux1_loss: 1.3189 - aux2_loss: 1.5059 - main_accuracy: 0.5309 - aux1_accuracy: 0.6256 - aux2_accuracy: 0.5792 - val_loss: 2.7876 - val_main_loss: 1.1100 - val_aux1_loss: 0.7757 - val_aux2_loss: 0.9019 - val_main_accuracy: 0.6694 - val_aux1_accuracy: 0.7610 - val_aux2_accuracy: 0.7190
# Epoch 2/30
# 1448/1448 [==============================] - 274s 189ms/step - loss: 1.5358 - main_loss: 0.5863 - aux1_loss: 0.4418 - aux2_loss: 0.5077 - main_accuracy: 0.8156 - aux1_accuracy: 0.8616 - aux2_accuracy: 0.8405 - val_loss: 0.9890 - val_main_loss: 0.3612 - val_aux1_loss: 0.3146 - val_aux2_loss: 0.3132 - val_main_accuracy: 0.8855 - val_aux1_accuracy: 0.8993 - val_aux2_accuracy: 0.8950
# Epoch 3/30
# 1448/1448 [==============================] - 298s 206ms/step - loss: 0.8992 - main_loss: 0.3389 - aux1_loss: 0.2648 - aux2_loss: 0.2955 - main_accuracy: 0.8925 - aux1_accuracy: 0.9155 - aux2_accuracy: 0.9069 - val_loss: 0.4966 - val_main_loss: 0.2085 - val_aux1_loss: 0.1342 - val_aux2_loss: 0.1539 - val_main_accuracy: 0.9306 - val_aux1_accuracy: 0.9558 - val_aux2_accuracy: 0.9499
# Epoch 4/30
# 1448/1448 [==============================] - 281s 194ms/step - loss: 0.5813 - main_loss: 0.2160 - aux1_loss: 0.1726 - aux2_loss: 0.1927 - main_accuracy: 0.9294 - aux1_accuracy: 0.9440 - aux2_accuracy: 0.9388 - val_loss: 0.4287 - val_main_loss: 0.1647 - val_aux1_loss: 0.1301 - val_aux2_loss: 0.1340 - val_main_accuracy: 0.9411 - val_aux1_accuracy: 0.9527 - val_aux2_accuracy: 0.9543 aux2_loss: 0.1928 - main_accuracy: 0.9294 - aux1_accuracy: 0.9440 - aux2_accuracy: 0.
# Epoch 5/30
# 1448/1448 [==============================] - 302s 208ms/step - loss: 0.4067 - main_loss: 0.1497 - aux1_loss: 0.1230 - aux2_loss: 0.1339 - main_accuracy: 0.9516 - aux1_accuracy: 0.9594 - aux2_accuracy: 0.9565 - val_loss: 0.3153 - val_main_loss: 0.1420 - val_aux1_loss: 0.0831 - val_aux2_loss: 0.0902 - val_main_accuracy: 0.9523 - val_aux1_accuracy: 0.9718 - val_aux2_accuracy: 0.9687
# Epoch 6/30
# 1448/1448 [==============================] - 299s 207ms/step - loss: 0.3039 - main_loss: 0.1090 - aux1_loss: 0.0946 - aux2_loss: 0.1003 - main_accuracy: 0.9637 - aux1_accuracy: 0.9682 - aux2_accuracy: 0.9677 - val_loss: 0.1816 - val_main_loss: 0.0727 - val_aux1_loss: 0.0522 - val_aux2_loss: 0.0567 - val_main_accuracy: 0.9762 - val_aux1_accuracy: 0.9818 - val_aux2_accuracy: 0.9799
# Epoch 7/30
# 1448/1448 [==============================] - 280s 193ms/step - loss: 0.2349 - main_loss: 0.0856 - aux1_loss: 0.0737 - aux2_loss: 0.0755 - main_accuracy: 0.9705 - aux1_accuracy: 0.9758 - aux2_accuracy: 0.9752 - val_loss: 0.3800 - val_main_loss: 0.1602 - val_aux1_loss: 0.1047 - val_aux2_loss: 0.1152 - val_main_accuracy: 0.9484 - val_aux1_accuracy: 0.9630 - val_aux2_accuracy: 0.9591
# Epoch 8/30
# 1448/1448 [==============================] - 275s 190ms/step - loss: 0.1824 - main_loss: 0.0636 - aux1_loss: 0.0599 - aux2_loss: 0.0589 - main_accuracy: 0.9781 - aux1_accuracy: 0.9804 - aux2_accuracy: 0.9804 - val_loss: 0.1334 - val_main_loss: 0.0606 - val_aux1_loss: 0.0350 - val_aux2_loss: 0.0378 - val_main_accuracy: 0.9790 - val_aux1_accuracy: 0.9867 - val_aux2_accuracy: 0.9862
# Epoch 9/30
# 1448/1448 [==============================] - 307s 212ms/step - loss: 0.1432 - main_loss: 0.0520 - aux1_loss: 0.0452 - aux2_loss: 0.0460 - main_accuracy: 0.9829 - aux1_accuracy: 0.9850 - aux2_accuracy: 0.9844 - val_loss: 0.2579 - val_main_loss: 0.1161 - val_aux1_loss: 0.0655 - val_aux2_loss: 0.0764 - val_main_accuracy: 0.9652 - val_aux1_accuracy: 0.9799 - val_aux2_accuracy: 0.9757
# Epoch 10/30
# 1448/1448 [==============================] - 273s 188ms/step - loss: 0.1202 - main_loss: 0.0425 - aux1_loss: 0.0396 - aux2_loss: 0.0382 - main_accuracy: 0.9859 - aux1_accuracy: 0.9863 - aux2_accuracy: 0.9871 - val_loss: 0.1850 - val_main_loss: 0.0660 - val_aux1_loss: 0.0591 - val_aux2_loss: 0.0599 - val_main_accuracy: 0.9777 - val_aux1_accuracy: 0.9801 - val_aux2_accuracy: 0.9814
# Epoch 11/30
# 1448/1448 [==============================] - 268s 185ms/step - loss: 0.1004 - main_loss: 0.0357 - aux1_loss: 0.0325 - aux2_loss: 0.0323 - main_accuracy: 0.9882 - aux1_accuracy: 0.9895 - aux2_accuracy: 0.9893 - val_loss: 0.0593 - val_main_loss: 0.0258 - val_aux1_loss: 0.0160 - val_aux2_loss: 0.0175 - val_main_accuracy: 0.9913 - val_aux1_accuracy: 0.9943 - val_aux2_accuracy: 0.9936
# Epoch 12/30
# 1448/1448 [==============================] - 271s 187ms/step - loss: 0.0762 - main_loss: 0.0276 - aux1_loss: 0.0238 - aux2_loss: 0.0248 - main_accuracy: 0.9912 - aux1_accuracy: 0.9915 - aux2_accuracy: 0.9918 - val_loss: 0.2814 - val_main_loss: 0.1131 - val_aux1_loss: 0.0840 - val_aux2_loss: 0.0843 - val_main_accuracy: 0.9608 - val_aux1_accuracy: 0.9707 - val_aux2_accuracy: 0.9702
# Epoch 13/30
# 1448/1448 [==============================] - 271s 187ms/step - loss: 0.0663 - main_loss: 0.0221 - aux1_loss: 0.0234 - aux2_loss: 0.0208 - main_accuracy: 0.9925 - aux1_accuracy: 0.9923 - aux2_accuracy: 0.9931 - val_loss: 0.1106 - val_main_loss: 0.0511 - val_aux1_loss: 0.0340 - val_aux2_loss: 0.0255 - val_main_accuracy: 0.9836 - val_aux1_accuracy: 0.9895 - val_aux2_accuracy: 0.9915
# Epoch 14/30
# 1448/1448 [==============================] - 275s 190ms/step - loss: 0.0542 - main_loss: 0.0178 - aux1_loss: 0.0200 - aux2_loss: 0.0165 - main_accuracy: 0.9939 - aux1_accuracy: 0.9937 - aux2_accuracy: 0.9940 - val_loss: 0.0727 - val_main_loss: 0.0341 - val_aux1_loss: 0.0181 - val_aux2_loss: 0.0205 - val_main_accuracy: 0.9882 - val_aux1_accuracy: 0.9941 - val_aux2_accuracy: 0.9932
# Epoch 15/30
# 1448/1448 [==============================] - 280s 193ms/step - loss: 0.0455 - main_loss: 0.0147 - aux1_loss: 0.0162 - aux2_loss: 0.0146 - main_accuracy: 0.9946 - aux1_accuracy: 0.9944 - aux2_accuracy: 0.9952 - val_loss: 0.0747 - val_main_loss: 0.0309 - val_aux1_loss: 0.0221 - val_aux2_loss: 0.0217 - val_main_accuracy: 0.9897 - val_aux1_accuracy: 0.9936 - val_aux2_accuracy: 0.9934
# Epoch 16/30
# 1448/1448 [==============================] - 274s 189ms/step - loss: 0.0375 - main_loss: 0.0121 - aux1_loss: 0.0145 - aux2_loss: 0.0110 - main_accuracy: 0.9960 - aux1_accuracy: 0.9953 - aux2_accuracy: 0.9963 - val_loss: 0.0494 - val_main_loss: 0.0235 - val_aux1_loss: 0.0137 - val_aux2_loss: 0.0122 - val_main_accuracy: 0.9921 - val_aux1_accuracy: 0.9956 - val_aux2_accuracy: 0.9959
# Epoch 17/30
# 1448/1448 [==============================] - 277s 191ms/step - loss: 0.0318 - main_loss: 0.0095 - aux1_loss: 0.0127 - aux2_loss: 0.0096 - main_accuracy: 0.9967 - aux1_accuracy: 0.9956 - aux2_accuracy: 0.9969 - val_loss: 0.0636 - val_main_loss: 0.0304 - val_aux1_loss: 0.0148 - val_aux2_loss: 0.0183 - val_main_accuracy: 0.9910 - val_aux1_accuracy: 0.9959 - val_aux2_accuracy: 0.9936
# Epoch 18/30
# 1448/1448 [==============================] - 278s 192ms/step - loss: 0.0280 - main_loss: 0.0083 - aux1_loss: 0.0114 - aux2_loss: 0.0083 - main_accuracy: 0.9971 - aux1_accuracy: 0.9963 - aux2_accuracy: 0.9975 - val_loss: 0.0410 - val_main_loss: 0.0147 - val_aux1_loss: 0.0125 - val_aux2_loss: 0.0137 - val_main_accuracy: 0.9952 - val_aux1_accuracy: 0.9963 - val_aux2_accuracy: 0.9952
# Epoch 19/30
# 1448/1448 [==============================] - 277s 191ms/step - loss: 0.0220 - main_loss: 0.0064 - aux1_loss: 0.0100 - aux2_loss: 0.0056 - main_accuracy: 0.9980 - aux1_accuracy: 0.9968 - aux2_accuracy: 0.9982 - val_loss: 0.0371 - val_main_loss: 0.0141 - val_aux1_loss: 0.0114 - val_aux2_loss: 0.0117 - val_main_accuracy: 0.9952 - val_aux1_accuracy: 0.9972 - val_aux2_accuracy: 0.9967
# Epoch 20/30
# 1448/1448 [==============================] - 278s 192ms/step - loss: 0.0234 - main_loss: 0.0065 - aux1_loss: 0.0099 - aux2_loss: 0.0070 - main_accuracy: 0.9977 - aux1_accuracy: 0.9969 - aux2_accuracy: 0.9976 - val_loss: 0.0479 - val_main_loss: 0.0202 - val_aux1_loss: 0.0137 - val_aux2_loss: 0.0140 - val_main_accuracy: 0.9939 - val_aux1_accuracy: 0.9969 - val_aux2_accuracy: 0.9959
# Epoch 21/30
# 1448/1448 [==============================] - 277s 191ms/step - loss: 0.0199 - main_loss: 0.0058 - aux1_loss: 0.0087 - aux2_loss: 0.0054 - main_accuracy: 0.9981 - aux1_accuracy: 0.9974 - aux2_accuracy: 0.9982 - val_loss: 0.0604 - val_main_loss: 0.0239 - val_aux1_loss: 0.0179 - val_aux2_loss: 0.0186 - val_main_accuracy: 0.9936 - val_aux1_accuracy: 0.9939 - val_aux2_accuracy: 0.9939
# Epoch 22/30
# 1448/1448 [==============================] - 277s 191ms/step - loss: 0.0178 - main_loss: 0.0047 - aux1_loss: 0.0078 - aux2_loss: 0.0052 - main_accuracy: 0.9985 - aux1_accuracy: 0.9973 - aux2_accuracy: 0.9983 - val_loss: 0.0382 - val_main_loss: 0.0154 - val_aux1_loss: 0.0115 - val_aux2_loss: 0.0113 - val_main_accuracy: 0.9952 - val_aux1_accuracy: 0.9969 - val_aux2_accuracy: 0.9965
# Epoch 23/30
# 1448/1448 [==============================] - 272s 188ms/step - loss: 0.0138 - main_loss: 0.0035 - aux1_loss: 0.0065 - aux2_loss: 0.0039 - main_accuracy: 0.9989 - aux1_accuracy: 0.9981 - aux2_accuracy: 0.9988 - val_loss: 0.0478 - val_main_loss: 0.0163 - val_aux1_loss: 0.0165 - val_aux2_loss: 0.0150 - val_main_accuracy: 0.9963 - val_aux1_accuracy: 0.9958 - val_aux2_accuracy: 0.9958
# Epoch 24/30
# 1448/1448 [==============================] - 273s 188ms/step - loss: 0.0144 - main_loss: 0.0037 - aux1_loss: 0.0063 - aux2_loss: 0.0043 - main_accuracy: 0.9988 - aux1_accuracy: 0.9980 - aux2_accuracy: 0.9986 - val_loss: 0.0421 - val_main_loss: 0.0149 - val_aux1_loss: 0.0145 - val_aux2_loss: 0.0127 - val_main_accuracy: 0.9963 - val_aux1_accuracy: 0.9959 - val_aux2_accuracy: 0.9961
# Epoch 25/30
# 1448/1448 [==============================] - 278s 192ms/step - loss: 0.0147 - main_loss: 0.0038 - aux1_loss: 0.0068 - aux2_loss: 0.0041 - main_accuracy: 0.9987 - aux1_accuracy: 0.9979 - aux2_accuracy: 0.9986 - val_loss: 0.0309 - val_main_loss: 0.0127 - val_aux1_loss: 0.0090 - val_aux2_loss: 0.0092 - val_main_accuracy: 0.9963 - val_aux1_accuracy: 0.9972 - val_aux2_accuracy: 0.9978
# Epoch 26/30
# 1448/1448 [==============================] - 284s 196ms/step - loss: 0.0125 - main_loss: 0.0029 - aux1_loss: 0.0058 - aux2_loss: 0.0038 - main_accuracy: 0.9991 - aux1_accuracy: 0.9981 - aux2_accuracy: 0.9989 - val_loss: 0.0358 - val_main_loss: 0.0135 - val_aux1_loss: 0.0110 - val_aux2_loss: 0.0113 - val_main_accuracy: 0.9961 - val_aux1_accuracy: 0.9967 - val_aux2_accuracy: 0.9972
# Epoch 27/30
# 1448/1448 [==============================] - 279s 193ms/step - loss: 0.0120 - main_loss: 0.0025 - aux1_loss: 0.0063 - aux2_loss: 0.0032 - main_accuracy: 0.9993 - aux1_accuracy: 0.9980 - aux2_accuracy: 0.9989 - val_loss: 0.0337 - val_main_loss: 0.0118 - val_aux1_loss: 0.0109 - val_aux2_loss: 0.0110 - val_main_accuracy: 0.9967 - val_aux1_accuracy: 0.9974 - val_aux2_accuracy: 0.9974
# Epoch 28/30
# 1448/1448 [==============================] - 275s 190ms/step - loss: 0.0113 - main_loss: 0.0027 - aux1_loss: 0.0051 - aux2_loss: 0.0035 - main_accuracy: 0.9991 - aux1_accuracy: 0.9984 - aux2_accuracy: 0.9988 - val_loss: 0.0406 - val_main_loss: 0.0146 - val_aux1_loss: 0.0105 - val_aux2_loss: 0.0155 - val_main_accuracy: 0.9976 - val_aux1_accuracy: 0.9978 - val_aux2_accuracy: 0.9963
# Epoch 29/30
# 1448/1448 [==============================] - 272s 188ms/step - loss: 0.0088 - main_loss: 0.0018 - aux1_loss: 0.0042 - aux2_loss: 0.0028 - main_accuracy: 0.9995 - aux1_accuracy: 0.9988 - aux2_accuracy: 0.9993 - val_loss: 0.0491 - val_main_loss: 0.0200 - val_aux1_loss: 0.0137 - val_aux2_loss: 0.0155 - val_main_accuracy: 0.9950 - val_aux1_accuracy: 0.9952 - val_aux2_accuracy: 0.9963
# Epoch 30/30
# 1448/1448 [==============================] - 276s 190ms/step - loss: 0.0087 - main_loss: 0.0015 - aux1_loss: 0.0048 - aux2_loss: 0.0025 - main_accuracy: 0.9995 - aux1_accuracy: 0.9985 - aux2_accuracy: 0.9993 - val_loss: 0.0289 - val_main_loss: 0.0112 - val_aux1_loss: 0.0087 - val_aux2_loss: 0.0090 - val_main_accuracy: 0.9971 - val_aux1_accuracy: 0.9976 - val_aux2_accuracy: 0.9976

# %%
model.evaluate(test_ds)
# Out:
# 182/182 [==============================] - 166s 58ms/step - loss: 0.0572 - main_loss: 0.0187 - aux1_loss: 0.0189 - aux2_loss: 0.0197 - main_accuracy: 0.9971 - aux1_accuracy: 0.9971 - aux2_accuracy: 0.9978
# [0.05724366754293442,
#  0.018717117607593536,
#  0.01887056604027748,
#  0.019655978307127953,
#  0.9970695972442627,
#  0.9970695972442627,
#  0.997802197933197]

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(image_batch[i].numpy())
    img_array = tf.expand_dims(img_array, 0) #create a batch
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])),2)
    return predicted_class, confidence

# %%
# 1st batch,9 images
import numpy as np
from sklearn.metrics import f1_score
over_all_actual_encoded = []
over_all_predicted_encoded = []

plt.figure(figsize=(15, 15))
for image_batch, label_batch in test_ds.take(10):

    for i in range(9):
        actualencoded = []
        predicted_encoded = []
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, image_batch[i].numpy())
        predicted_encoded.append(encoded_class.get(predicted_class))
#         print(predict(model, image_batch[i].numpy()))
        actual_class = class_names[label_batch[i]]
        actualencoded.append(encoded_class.get(actual_class))
        over_all_actual_encoded.append(encoded_class.get(actual_class))
        over_all_predicted_encoded.append(encoded_class.get(predicted_class))
        f1 = f1_score(actualencoded,predicted_encoded,average = 'micro')
        
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}.\n Confidence: {confidence}.\n F1_SCore: {f1}%")
        
        plt.axis("off")

# %%
f1_score(over_all_actual_encoded,over_all_predicted_encoded,average = 'micro')
# Out:
# 1.0

# %%
model_version = 34
model.save(f"../model34/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: ../model34/34\assets

# %%
# equivalent to: model.save("model.h5")
from tensorflow.keras.models import save_model
save_model(model, "model_Google_color_V4_80_20.h5")
